# %%
import pandas as pd
import numpy as np

# %%
original = "George and Paul were influential\
contains the Hungarian letter ō\
but is frequnetly mistaken"

# %%
original.lower()
# Out:
# 'george and paul were influentialcontains the hungarian letter ōbut is frequnetly mistaken'

# %%
import unicodedata

original = unicodedata.normalize('NFKD', original).encode('ascii', 'ignore').decode('utf-8').lower()
original
# Out:
# 'george and paul were influentialcontains the hungarian letter obut is frequnetly mistaken'

# %%
import re

# %%
original = re.sub('[^a-z0-9\'\s]', '', original)

# %%
import nltk

# %%
tokenize = nltk.tokenize.ToktokTokenizer()
tokenize

# %%
tokenize.tokenize(original, return_str = True)
# Out:
# 'eorge and aul were influentialcontains the ungarian letter obut is frequnetly mistaken'

# %%
ps = nltk.porter.PorterStemmer()
ps

# %%
ps.stem('calling'), ps.stem('calls'), ps.stem('called'), ps.stem('call')
# Out:
# ('call', 'call', 'call', 'call')

# %%
ps.stem('house'), ps.stem('housing')
# Out:
# ('hous', 'hous')

# %%
ps.stem(original)
# Out:
# 'eorge and aul were influentialcontains the ungarian letter obut is frequnetly mistaken'

# %%
#run the first time
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /Users/burton/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/burton/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/burton/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/burton/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/burton/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to
# ...

# %%
from nltk.corpus import stopwords

# %%
#1.
def basic_clean(string):
    new_string = unicodedata.normalize('NFKD', string).encode('ascii', 'ignore').decode('utf-8').lower()
    return new_string

# %%
#2.
def tokenize(string):
    tokenize = nltk.tokenize.ToktokTokenizer()
    token = tokenize.tokenize(string, return_str = True)
    return token

# %%
#3.
def stem(string):
    ps = nltk.porter.PorterStemmer()
    ps.stem('house'), ps.stem('housing')
    stemmed = ps.stem(string)
    return stemmed

# %%
#4.
def lemmatize(string):
    wnl = nltk.stem.WordNetLemmatizer()
    for word in string
    print('stem:', ps.stem(word), '-- lemma:', wnl.lemmatize(word))

# %%
#5.
from nltk.corpus import stopwords

# %%
def remove_stopwords(string):
    stopwords_english = stopwords.words('english')
    stop = [word for word in original.split() if word not in stopwords_english]
    return stop

# %%
#6.
categories = [li.text.lower() for li in soup.select('li')][1:]
categories[0] = 'national'

inshorts = []

for category in categories:
    
    url = 'https://inshorts.com/en/read' + '/' + category
    response = get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    titles = [span.text for span in soup.find_all('span', itemprop='headline')]
    contents = [div.text for div in soup.find_all('div', itemprop='articleBody')]
    
    for i in range(len(titles)):
        
        article = {
            'title': titles[i],
            'content': contents[i],
            'category': category,
        }
        
        inshorts.append(article)

# %%
news_df = pd.DataFrame(inshorts)
news_df
# Out:
#                                                 title  \
# 0   Moscow-Goa flight gets bomb threat, makes emer...
# 1   Joshimath divided into 3 zones, govt says most...
# 2   Which states have reported COVID-19 variant XB...
# 3   I decided to wear t-shirt till I shiver after ...
# 4   1 dead, 40 injured after speeding bus overturn...
# 5   Sec 144 imposed in Assam's Karimganj after Baj...
# 6   Vistara's Bhubaneswar-bound flight returns to ...
# 7   Rajasthan MLA Johari Lal Meena's son arrested ...
# 8   2 children charred to death, 4 other siblings ...
# 9   IAS officer Khemka transferred for 55th time, ...
# 10  Over 200 shanties gutted in major fire at slum...
# 11  Priyanka Gandhi to address Cong women's conven...
# 12  A 'new Joshimath town' should be built by Cent...
# 13  Most DMK people are not Tamilians: Ex-BJP MP o...
# 14  Jharkhand BJP MLA sent to jail in a 10-year-ol...
# 15  RSS never chants 'Har Har Mahadev', it removed...
# ...

# %%
from requests import get
from bs4 import BeautifulSoup
import os
import pandas as pd

# %%
#7.
url = 'https://codeup.com/blog/'
headers = {'User-Agent': 'Codeup Data Science'}
response = get(url, headers=headers)

soup = BeautifulSoup(response.content, 'html.parser')

links = [link['href'] for link in soup.select('.more-link')]

articles = []

for url in links:
    
    url_response = get(url, headers=headers)
    soup = BeautifulSoup(url_response.text)
    
    title = soup.find('h1', class_='entry-title').text
    content = soup.find('div', class_='entry-content').text.strip()
    
    article_dict = {
        'title': title,
        'content': content
    }
    
    articles.append(article_dict)

# %%
codeup_df = pd.DataFrame(articles)
codeup_df
# Out:
#                                                title  \
# 0               Become a Data Scientist in 6 Months!
# 1             Hiring Tech Talent Around the Holidays
# 2   Cloud Administration Program New Funding Options
# 3  Why Dallas is a Great Location for IT Professi...
# 4               Codeup is ranked #1 Best in DFW 2022
# 5                     Codeup’s Scholarship Offerings
#
#                                              content
# 0  Are you feeling unfulfilled in your work but w...
# 1  Are you a hiring manager having trouble fillin...
# 2  Finding resources to fund your educational goa...
# 3  When breaking into a new career, it is importa...
# 4  We are excited to announce that Codeup ranked ...
# 5  In honor of November being National Scholarshi...

# %%
#9.
# if 493 KB, then lemmatized
# if 25, MB then stemmed
# if 200TB then stemmed
